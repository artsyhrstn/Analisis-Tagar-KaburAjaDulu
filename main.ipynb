# %% [markdown]
# # Inisialisasi Data

# %%
import pandas as pd

# Hasil Crawling
crawl_df = pd.read_csv('data//kad.csv')
crawl_df
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1895457424074494178  Fri Feb 28 12:54:00 +0000 2025             855
# 1    1895345579611521443  Fri Feb 28 05:29:34 +0000 2025              65
# 2    1895312943539200303  Fri Feb 28 03:19:53 +0000 2025             157
# 3    1895066745599336483  Thu Feb 27 11:01:35 +0000 2025           17884
# 4    1895018066637135963  Thu Feb 27 07:48:09 +0000 2025            1160
# ..                   ...                             ...             ...
# 231  1831921465211650170  Fri Sep 06 05:04:47 +0000 2024            3081
# 232  1825372271227060416  Mon Aug 19 03:20:37 +0000 2024            1243
# 233  1800178890641699308  Mon Jun 10 14:51:07 +0000 2024            4584
# 234  1788160002857050360  Wed May 08 10:52:21 +0000 2024              60
# 235  1767769001424527842  Wed Mar 13 04:25:48 +0000 2024             239
#
#                                              full_text               id_str  \
# 0    Akhirnya Pertamina terkapar di negeri sendiri....  1895457424074494178
# 1    Hari kerja terakhir karyawan Sritex... #Indone...  1895345579611521443
# 2    Teriak di medsos #KaburAjaDulu . Faktanya Yama...  1895312943539200303
# 3    Barusan banget buka website Imigrasi New Zeala...  1895066745599336483
# 4    Bye Indonesia #KaburAjaDulu https://t.co/LVgY8...  1895018066637135963
# ..                                                 ...                  ...
# 231  Coba sharing pengalaman pribadi kalian berjuan...  1831921465211650170
# 232  Halo. ak mau informasikan lowongan di tempat k...  1825372271227060416
# 233  Aku udah beberapa kali share caranya buat #Kab...  1800178890641699308
# 234  Selamat long weekend terkecuali buat diaspora ...  1788160002857050360
# 235  Yang mau kerja di company Jepang non IT positi...  1767769001424527842
#
#                                              image_url  \
# 0      https://pbs.twimg.com/media/Gk3o1j9akAAlaeC.jpg
# 1    https://pbs.twimg.com/ext_tw_video_thumb/18953...
# 2                                                  NaN
# 3                                                  NaN
# 4      https://pbs.twimg.com/media/Gkx04o7X0AAOFNB.jpg
# ..                                                 ...
# 231                                                NaN
# 232                                                NaN
# 233                                                NaN
# 234                                                NaN
# 235    https://pbs.twimg.com/media/GIhgiTGbsAEYwP0.jpg
#
#     in_reply_to_screen_name lang                  location  quote_count  \
# 0                       NaN   in                       NaN            7
# 1                       NaN   in           Jakarta Selatan            3
# 2                       NaN   in    DKI Jakarta, Indonesia           11
# 3                       NaN   in      Brisbane, Queensland          389
# 4                       NaN   in                       NaN           14
# ..                      ...  ...                       ...          ...
# 231                     NaN   in                 Indonesia          440
# 232                     NaN   in              Tokyo, Japan           87
# 233                     NaN   in  Busan, Republic of Korea           72
# 234                     NaN   in      Borobudur, Indonesia            5
# 235                     NaN   in                      神奈川県           17
#
#      reply_count  retweet_count  \
# 0             51            318
# 1             24             19
# 2            116             29
# 3            219           3759
# 4             35            186
# ..           ...            ...
# 231          151            732
# 232           34            385
# 233           36            866
# 234           14              1
# 235           30            138
#
#                                              tweet_url          user_id_str  \
# 0    https://x.com/Y_Radianto/status/18954574240744...  1529772993530167297
# 1    https://x.com/RickyKardjono/status/18953455796...            941458748
# 2    https://x.com/Franken_blues/status/18953129435...  1301242545888849921
# 3    https://x.com/AmirahWahdi/status/1895066745599...             68827009
# 4     https://x.com/qrivasi/status/1895018066637135963   752746497968484353
# ..                                                 ...                  ...
# 231  https://x.com/hrdbacot/status/1831921465211650170            501800437
# 232  https://x.com/farislmn/status/1825372271227060416             64129717
# 233  https://x.com/primawansatrio/status/1800178890...            104823513
# 234  https://x.com/lynxluna/status/1788160002857050360             69194832
# 235  https://x.com/praditdita/status/17677690014245...             61713426
#
#            username
# 0        Y_Radianto
# 1     RickyKardjono
# 2     Franken_blues
# 3       AmirahWahdi
# 4           qrivasi
# ..              ...
# 231        hrdbacot
# 232        farislmn
# 233  primawansatrio
# 234        lynxluna
# 235      praditdita
#
# [236 rows x 15 columns]

# %%
import matplotlib.pyplot as plt

# Google Trend
trend_df = pd.read_csv('data//multiTimeline.csv')

# Rename the column to remove the invalid string for conversion
trend_df.columns = ['Trend_Score']

# Convert the index to datetime for better visualization
trend_df.index = pd.to_datetime(trend_df.index, errors='coerce')

# Convert the trend score column to numeric, coercing errors to NaN
trend_df['Trend_Score'] = pd.to_numeric(trend_df['Trend_Score'], errors='coerce')

# Drop rows with NaN values in the index or Trend_Score column
trend_df = trend_df.dropna(subset=['Trend_Score']).dropna()

# Plot the Google Trend data
plt.figure(figsize=(12, 6))
plt.plot(trend_df.index, trend_df['Trend_Score'], color='blue', label='Indeks Tren Pencarian')
plt.title('Pencarian "Kabur Aja Dulu"')
plt.xlabel('Date')
plt.ylabel('Trend Score')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# C:\Users\hisbi\AppData\Local\Temp\ipykernel_21812\1482869149.py:10: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   trend_df.index = pd.to_datetime(trend_df.index, errors='coerce')

# %%
# Inisialisasi library yang digunakan

from mpl_toolkits.basemap import Basemap
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut

import matplotlib.pyplot as plt

# Deteksi lokasi dari teks
geolocator = Nominatim(user_agent="geoapi")

# Function to get latitude and longitude from location
def geocode_location(location):
    try:
        if pd.notna(location):
            loc = geolocator.geocode(location, timeout=10)
            if loc:
                return loc.latitude, loc.longitude
    except GeocoderTimedOut:
        pass
    return None, None

# Terapkan geocoding ke kolom 'location'
crawl_df['latitude'], crawl_df['longitude'] = zip(*crawl_df['location'].apply(geocode_location))

# Filter baris dengan kordinat yang valid
valid_locations = crawl_df.dropna(subset=['latitude', 'longitude'])

# Buat  Basemap instance
plt.figure(figsize=(12, 8))
m = Basemap(projection='merc', llcrnrlat=-60, urcrnrlat=80, llcrnrlon=-180, urcrnrlon=180, resolution='c')

# Visualisasi details pada basemap
m.drawcoastlines()
m.drawcountries()
m.fillcontinents(color='lightgray') # , lake_color='aqua'
m.drawmapboundary(fill_color='white')

# Plot lokasi
x, y = m(valid_locations['longitude'].values, valid_locations['latitude'].values)
m.scatter(x, y, marker='o', color='blue', zorder=5, s=10)

plt.title("Sebaran Cuitan #KaburAjaDulu")
plt.show()

# %% [markdown]
# # EDA

# %%
# Count locations in Indonesia
indonesia_count = crawl_df['location'].str.contains("Indonesia", na=False).sum()

# Count locations not in Indonesia
non_indonesia_count = len(crawl_df) - indonesia_count

print(f"Locations in Indonesia: {indonesia_count}")
print(f"Locations not in Indonesia: {non_indonesia_count}")
# Out:
# Locations in Indonesia: 62
# Locations not in Indonesia: 174

# %%
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut

# Initialize the geolocator
geolocator = Nominatim(user_agent="geoapi")

# Function to detect country from latitude and longitude
def detect_country(lat, lon):
    try:
        if pd.notna(lat) and pd.notna(lon):
            location = geolocator.reverse((lat, lon), timeout=10)
            if location and 'country' in location.raw['address']:
                return location.raw['address']['country']
    except GeocoderTimedOut:
        pass
    return None

# Apply the function to detect countries
valid_locations['detected_country'] = valid_locations.apply(
    lambda row: detect_country(row['latitude'], row['longitude']), axis=1
)

# Display the updated DataFrame
valid_locations[['latitude', 'longitude', 'detected_country']]
valid_locations.to_csv('data//kad_geocoded.csv', index=False)
# Out:
# C:\Users\hisbi\AppData\Local\Temp\ipykernel_18664\2889953572.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_locations['detected_country'] = valid_locations.apply(
#       latitude   longitude detected_country
# 1    -6.283818  106.804863        Indonesia
# 2    -6.175405  106.827168        Indonesia
# 3   -27.468968  153.023499        Australia
# 7    -6.176192  106.638216        Indonesia
# 9    -6.283818  106.804863        Indonesia
# ..         ...         ...              ...
# 231  -2.483383  117.890285        Indonesia
# 232  35.676860  139.763895               日本
# 233  35.179953  129.075236             대한민국
# 234  -7.607958  110.203824        Indonesia
# 235  35.434294  139.374753               日本
#
# [173 rows x 3 columns]

# %%
# Group by detected_country and count occurrences
country_counts = valid_locations['detected_country'].value_counts()

# Plot the pie chart
plt.figure(figsize=(10, 8))
country_counts.plot.pie(autopct='%1.1f%%', startangle=140, colors=colors)
plt.title('Distribution of Valid Locations by Country')
plt.ylabel('')  # Remove the y-axis label
plt.show()
# Out:
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# C:\Users\hisbi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\hisbi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 26412 (\N{CJK UNIFIED IDEOGRAPH-672C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# C:\Users\hisbi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\hisbi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\hisbi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48124 (\N{HANGUL SYLLABLE MIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\hisbi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# C:\Users\hisbi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 20013 (\N{CJK UNIFIED IDEOGRAPH-4E2D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\hisbi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 22269 (\N{CJK UNIFIED IDEOGRAPH-56FD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# C:\Users\hisbi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 33274 (\N{CJK UNIFIED IDEOGRAPH-81FA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\hisbi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 28771 (\N{CJK UNIFIED IDEOGRAPH-7063}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.

# %%
# Create a pivot table by detected_country and count occurrences, then rename the column and save to CSV
list_country = valid_locations['detected_country'].value_counts().rename("total")
list_country.to_csv('data//list_country.csv')

# %% [markdown]
# ## Urutkan Tertinggi

# %% [markdown]
# ### Likes

# %%
likes_crawl_df = crawl_df.sort_values(by='favorite_count', ascending=False)
likes_crawl_df
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 102  1891059049656930362  Sun Feb 16 09:36:26 +0000 2025           47541
# 116  1890712366884528542  Sat Feb 15 10:38:50 +0000 2025           44034
# 99   1891404280361349548  Mon Feb 17 08:28:15 +0000 2025           40950
# 143  1890038899269083464  Thu Feb 13 14:02:43 +0000 2025           40689
# 195  1887345545553059967  Thu Feb 06 03:40:17 +0000 2025           35795
# ..                   ...                             ...             ...
# 123  1890500987552510248  Fri Feb 14 20:38:53 +0000 2025              24
# 58   1891850290019651687  Tue Feb 18 14:00:32 +0000 2025              24
# 16   1893914172406042845  Mon Feb 24 06:41:40 +0000 2025              22
# 27   1893142329126723725  Sat Feb 22 03:34:38 +0000 2025              22
# 83   1891475351752065240  Mon Feb 17 13:10:40 +0000 2025              18
#
#                                              full_text               id_str  \
# 102  #intinyadeh Menteri Bahlil blg yg #KaburAjaDul...  1891059049656930362
# 116  Video yang dihapus oleh tiktok ditonton lebih ...  1890712366884528542
# 99   Bosen di INDONESIA? Mau kabur? berikut TUTORIA...  1891404280361349548
# 143  putra putri terbaik bangsa lebih milih #KaburA...  1890038899269083464
# 195  Yg punya info loker di LN tlg share di sini #K...  1887345545553059967
# ..                                                 ...                  ...
# 123  jangan tanya nasionalis ku bung #KaburAjaDulu ...  1890500987552510248
# 58   #IndonesiaGelap #IndonesiaGelap2025 Mending ka...  1891850290019651687
# 16   galau hari terakhir sebelum #KaburAjaDulu http...  1893914172406042845
# 27   kalian pengen minggat ga? kalo iya ke mana? #K...  1893142329126723725
# 83   lah bodoamat gasss #kaburajadulu https://t.co/...  1891475351752065240
#
#                                              image_url  \
# 102                                                NaN
# 116  https://pbs.twimg.com/ext_tw_video_thumb/18907...
# 99     https://pbs.twimg.com/media/Gj-eKlhbkAAHZbO.jpg
# 143    https://pbs.twimg.com/media/GjrEW8oaoAEHzzv.jpg
# 195                                                NaN
# ..                                                 ...
# 123  https://pbs.twimg.com/amplify_video_thumb/1889...
# 58                                                 NaN
# 16   https://pbs.twimg.com/amplify_video_thumb/1893...
# 27                                                 NaN
# 83   https://pbs.twimg.com/amplify_video_thumb/1891...
#
#     in_reply_to_screen_name lang                        location  quote_count  \
# 102                     NaN   in  di ujung lidah tapi gak keluar          327
# 116                     NaN   in                             NaN          381
# 99                      NaN   in             Klaten, Jawa Tengah          361
# 143                     NaN   in                             NaN          742
# 195                     NaN   in                       Indonesia          396
# ..                      ...  ...                             ...          ...
# 123                     NaN   in                   (•͡˘˛˘ •͡)┌П┐            0
# 58                      NaN   in             Sukabumi, Indonesia            0
# 16                      NaN   in                  Warsaw, Poland            1
# 27                      NaN   in                             NaN            0
# 83                      NaN   in                   (•͡˘˛˘ •͡)┌П┐            0
#
#      reply_count  retweet_count  \
# 102          278          11858
# 116          466          13551
# 99           471           5897
# 143          775           6491
# 195          521           7049
# ..           ...            ...
# 123           18              3
# 58            20              1
# 16            24              0
# 27            22              0
# 83            15              0
#
#                                              tweet_url          user_id_str  \
# 102  https://x.com/intinyadeh/status/18910590496569...  1525880650829467648
# 116  https://x.com/AbanggSayur/status/1890712366884...  1102960516832550912
# 99   https://x.com/DndySaputra/status/1891404280361...           3152945558
# 143  https://x.com/awesomeposted/status/18900388992...  1547936519695978498
# 195  https://x.com/berlianidris/status/188734554555...            230696471
# ..                                                 ...                  ...
# 123  https://x.com/suk4bebek_v2/status/189050098755...  1656037556700721152
# 58   https://x.com/putr1432/status/1891850290019651687  1691307345807282176
# 16    https://x.com/imdinoz/status/1893914172406042845  1544130046159269888
# 27     https://x.com/vrnitt/status/1893142329126723725  1106892110857302017
# 83   https://x.com/suk4bebek_v2/status/189147535175...  1656037556700721152
#
#           username                         country   latitude   longitude
# 102     intinyadeh  di ujung lidah tapi gak keluar        NaN         NaN
# 116    AbanggSayur                             NaN        NaN         NaN
# 99     DndySaputra                     Jawa Tengah  -7.673239  110.628478
# 143  awesomeposted                             NaN        NaN         NaN
# 195   berlianidris                       Indonesia  -2.483383  117.890285
# ..             ...                             ...        ...         ...
# 123   suk4bebek_v2                   (•͡˘˛˘ •͡)┌П┐  60.912951   46.357467
# 58        putr1432                       Indonesia  -6.919929  106.926509
# 16         imdinoz                          Poland  52.233717   21.071432
# 27          vrnitt                             NaN        NaN         NaN
# 83    suk4bebek_v2                   (•͡˘˛˘ •͡)┌П┐  60.912951   46.357467
#
# [236 rows x 18 columns]

# %% [markdown]
# ### Retweet

# %%
retweet_crawl_df = crawl_df.sort_values(by='favorite_count', ascending=False)
retweet_crawl_df
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 102  1891059049656930362  Sun Feb 16 09:36:26 +0000 2025           47541
# 116  1890712366884528542  Sat Feb 15 10:38:50 +0000 2025           44034
# 99   1891404280361349548  Mon Feb 17 08:28:15 +0000 2025           40950
# 143  1890038899269083464  Thu Feb 13 14:02:43 +0000 2025           40689
# 195  1887345545553059967  Thu Feb 06 03:40:17 +0000 2025           35795
# ..                   ...                             ...             ...
# 123  1890500987552510248  Fri Feb 14 20:38:53 +0000 2025              24
# 58   1891850290019651687  Tue Feb 18 14:00:32 +0000 2025              24
# 16   1893914172406042845  Mon Feb 24 06:41:40 +0000 2025              22
# 27   1893142329126723725  Sat Feb 22 03:34:38 +0000 2025              22
# 83   1891475351752065240  Mon Feb 17 13:10:40 +0000 2025              18
#
#                                              full_text               id_str  \
# 102  #intinyadeh Menteri Bahlil blg yg #KaburAjaDul...  1891059049656930362
# 116  Video yang dihapus oleh tiktok ditonton lebih ...  1890712366884528542
# 99   Bosen di INDONESIA? Mau kabur? berikut TUTORIA...  1891404280361349548
# 143  putra putri terbaik bangsa lebih milih #KaburA...  1890038899269083464
# 195  Yg punya info loker di LN tlg share di sini #K...  1887345545553059967
# ..                                                 ...                  ...
# 123  jangan tanya nasionalis ku bung #KaburAjaDulu ...  1890500987552510248
# 58   #IndonesiaGelap #IndonesiaGelap2025 Mending ka...  1891850290019651687
# 16   galau hari terakhir sebelum #KaburAjaDulu http...  1893914172406042845
# 27   kalian pengen minggat ga? kalo iya ke mana? #K...  1893142329126723725
# 83   lah bodoamat gasss #kaburajadulu https://t.co/...  1891475351752065240
#
#                                              image_url  \
# 102                                                NaN
# 116  https://pbs.twimg.com/ext_tw_video_thumb/18907...
# 99     https://pbs.twimg.com/media/Gj-eKlhbkAAHZbO.jpg
# 143    https://pbs.twimg.com/media/GjrEW8oaoAEHzzv.jpg
# 195                                                NaN
# ..                                                 ...
# 123  https://pbs.twimg.com/amplify_video_thumb/1889...
# 58                                                 NaN
# 16   https://pbs.twimg.com/amplify_video_thumb/1893...
# 27                                                 NaN
# 83   https://pbs.twimg.com/amplify_video_thumb/1891...
#
#     in_reply_to_screen_name lang                        location  quote_count  \
# 102                     NaN   in  di ujung lidah tapi gak keluar          327
# 116                     NaN   in                             NaN          381
# 99                      NaN   in             Klaten, Jawa Tengah          361
# 143                     NaN   in                             NaN          742
# 195                     NaN   in                       Indonesia          396
# ..                      ...  ...                             ...          ...
# 123                     NaN   in                   (•͡˘˛˘ •͡)┌П┐            0
# 58                      NaN   in             Sukabumi, Indonesia            0
# 16                      NaN   in                  Warsaw, Poland            1
# 27                      NaN   in                             NaN            0
# 83                      NaN   in                   (•͡˘˛˘ •͡)┌П┐            0
#
#      reply_count  retweet_count  \
# 102          278          11858
# 116          466          13551
# 99           471           5897
# 143          775           6491
# 195          521           7049
# ..           ...            ...
# 123           18              3
# 58            20              1
# 16            24              0
# 27            22              0
# 83            15              0
#
#                                              tweet_url          user_id_str  \
# 102  https://x.com/intinyadeh/status/18910590496569...  1525880650829467648
# 116  https://x.com/AbanggSayur/status/1890712366884...  1102960516832550912
# 99   https://x.com/DndySaputra/status/1891404280361...           3152945558
# 143  https://x.com/awesomeposted/status/18900388992...  1547936519695978498
# 195  https://x.com/berlianidris/status/188734554555...            230696471
# ..                                                 ...                  ...
# 123  https://x.com/suk4bebek_v2/status/189050098755...  1656037556700721152
# 58   https://x.com/putr1432/status/1891850290019651687  1691307345807282176
# 16    https://x.com/imdinoz/status/1893914172406042845  1544130046159269888
# 27     https://x.com/vrnitt/status/1893142329126723725  1106892110857302017
# 83   https://x.com/suk4bebek_v2/status/189147535175...  1656037556700721152
#
#           username                         country   latitude   longitude
# 102     intinyadeh  di ujung lidah tapi gak keluar        NaN         NaN
# 116    AbanggSayur                             NaN        NaN         NaN
# 99     DndySaputra                     Jawa Tengah  -7.673239  110.628478
# 143  awesomeposted                             NaN        NaN         NaN
# 195   berlianidris                       Indonesia  -2.483383  117.890285
# ..             ...                             ...        ...         ...
# 123   suk4bebek_v2                   (•͡˘˛˘ •͡)┌П┐  60.912951   46.357467
# 58        putr1432                       Indonesia  -6.919929  106.926509
# 16         imdinoz                          Poland  52.233717   21.071432
# 27          vrnitt                             NaN        NaN         NaN
# 83    suk4bebek_v2                   (•͡˘˛˘ •͡)┌П┐  60.912951   46.357467
#
# [236 rows x 18 columns]

# %% [markdown]
# # Ratio (quote tweet > like)

# %%
quote_greater_than_favorite = crawl_df[crawl_df['quote_count'] > crawl_df['favorite_count']]
quote_greater_than_favorite
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 85   1891470533281165513  Mon Feb 17 12:51:31 +0000 2025             276
# 115  1890752284205666672  Sat Feb 15 13:17:27 +0000 2025             889
#
#                                              full_text               id_str  \
# 85   Menteri ATR/BPN Nusron Wahid tanggapi tagar #K...  1891470533281165513
# 115  Hukum #KaburAjaDulu ke negeri non muslim ? htt...  1890752284205666672
#
#                                              image_url  \
# 85                                                 NaN
# 115  https://pbs.twimg.com/ext_tw_video_thumb/18907...
#
#     in_reply_to_screen_name lang   location  quote_count  reply_count  \
# 85                      NaN   in        NaN          305          647
# 115                     NaN   in  Indonesia         1735          886
#
#      retweet_count                                          tweet_url  \
# 85              62  https://x.com/detikcom/status/1891470533281165513
# 115            218  https://x.com/fotodakwah/status/18907522842056...
#
#      user_id_str    username    country  latitude   longitude
# 85      69183155    detikcom        NaN       NaN         NaN
# 115    105428309  fotodakwah  Indonesia -2.483383  117.890285
